# %%
# scatter plot of blobs dataset
import matplotlib.pyplot as plt
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot
from numpy import where
import seaborn as sns
# %matplotlib inline

# %%
# load preprocessed dataset
data=pd.read_csv("traindata.csv")

# iterating the columns with their indices
for idx ,col in enumerate(data.columns): 
    print(str(idx) + " " + str(col))
# Out:
# 0  Packet Length Variance
# 1  Packet Length Std
# 2  Max Packet Length
# 3 Fwd Packets/s
# 4  Fwd IAT Max
# 5  Flow IAT Max
# 6 Init_Win_bytes_forward
# 7  Fwd Packet Length Mean
# 8  Fwd IAT Std
# 9  Fwd IAT Mean
# 10  Flow IAT Std
# 11  Packet Length Mean
# 12  Min Packet Length
# 13  Flow IAT Mean
# 14  Flow Duration
# 15  Average Packet Size
# 16  Fwd Packet Length Std
# 17  Fwd Packet Length Min
# 18  Fwd Packet Length Max
# 19 Fwd IAT Total
# 20 Label

# %%
sns.boxplot(x=data[' Packet Length Variance'])

# %%
sns.boxplot(x=data[' Packet Length Std'])

# %%
sns.boxplot(x=data[' Max Packet Length'])

# %%
sns.boxplot(x=data['Fwd Packets/s'])

# %%
sns.boxplot(x=data[' Fwd IAT Max'])

# %%
sns.boxplot(x=data[' Flow IAT Max'])

# %%
sns.boxplot(x=data['Init_Win_bytes_forward'])

# %%
sns.boxplot(x=data[' Fwd Packet Length Mean'])

# %%
# Plotting the outliers for each feature using box plots
#separately for attack and benign classes

sns.set(rc={'figure.figsize':(20,13)}, font_scale=2, style='whitegrid')
plt.subplot(2,2,1)
sns.boxplot(x = 'Label', y = ' Packet Length Variance', data = data)
plt.subplot(2,2,2)
sns.boxplot(x = 'Label', y = ' Packet Length Std', data = data)
plt.subplot(2,2,3)
sns.boxplot(x = 'Label', y = ' Max Packet Length', data = data)
plt.subplot(2,2,4)
sns.boxplot(x = 'Label', y ='Fwd Packets/s', data = data)

# %%
sns.set(rc={'figure.figsize':(20,13)}, font_scale=2, style='whitegrid')
plt.subplot(2,2,1)
sns.boxplot(x = 'Label', y = ' Fwd IAT Max', data = data)
plt.subplot(2,2,2)
sns.boxplot(x = 'Label', y = ' Flow IAT Max', data = data)
plt.subplot(2,2,3)
sns.boxplot(x = 'Label', y =  'Init_Win_bytes_forward', data = data)
plt.subplot(2,2,4)
sns.boxplot(x = 'Label', y =' Fwd Packet Length Mean', data = data)

# %%
##visualizing outliers for a single feature
sns.boxplot(x = 'Label', y =' Packet Length Mean', data = data)

# %%
sns.set(rc={'figure.figsize':(20,13)}, font_scale=2, style='whitegrid')
plt.subplot(2,2,1)
sns.boxplot(x = 'Label', y = ' Fwd IAT Std', data = data)
plt.subplot(2,2,2)
sns.boxplot(x = 'Label', y = ' Fwd IAT Mean', data = data)
plt.subplot(2,2,3)
sns.boxplot(x = 'Label', y =  ' Flow IAT Std', data = data)
plt.subplot(2,2,4)
sns.boxplot(x = 'Label', y =' Packet Length Mean', data = data)

# %%
plt.subplot(2,2,1)
sns.boxplot(x = 'Label', y = ' Min Packet Length', data = data)
plt.subplot(2,2,2)
sns.boxplot(x = 'Label', y = ' Flow IAT Mean', data = data)
plt.subplot(2,2,3)
sns.boxplot(x = 'Label', y =  ' Flow Duration', data = data)
plt.subplot(2,2,4)
sns.boxplot(x = 'Label', y =' Average Packet Size', data = data)

# %%
sns.boxplot(x=data[' Flow Duration']) ##outliers for both attack and benign class together

# %%
plt.subplot(2,2,1)
sns.boxplot(x = 'Label', y = ' Fwd Packet Length Std', data = data)
plt.subplot(2,2,2)
sns.boxplot(x = 'Label', y = ' Fwd Packet Length Min', data = data)
plt.subplot(2,2,3)
sns.boxplot(x = 'Label', y = ' Fwd Packet Length Max', data = data)
plt.subplot(2,2,4)
sns.boxplot(x = 'Label', y ='Fwd IAT Total', data = data)
